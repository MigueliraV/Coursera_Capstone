# %% [markdown]
# # Miguel Lira´s Coursera capstone notebook

# %% [markdown]
# ## In this notebook I will develop the entire Coursera_Capstone project. Please any comments let me know.

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
